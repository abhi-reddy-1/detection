# %%
#install the requirements from requirements.txt
#pip install -qr requirements.txt

#inference
#the images with bounding boxes are saved to ../runs/detect/

# %run detect.py --weights runs/train/yolov5s_results/weights/best.pt --img 416 --conf 0.4 --source test
# Out:
# Namespace(agnostic_nms=False, augment=False, classes=None, conf_thres=0.4, device='', exist_ok=False, img_size=416, iou_thres=0.45, name='exp', project='runs/detect', save_conf=False, save_txt=False, source='test', update=False, view_img=False, weights=['runs/train/yolov5s_results/weights/best.pt'])
# YOLOv5  torch 1.8.1+cpu CPU
#
# Model Summary: 232 layers, 7246518 parameters, 0 gradients, 16.8 GFLOPS
# Fusing layers...
# image 1/169 /home/abhireddy/Downloads/edge/test/car_100.jpg: 320x416 1 license_plate, Done. (0.108s)
# image 2/169 /home/abhireddy/Downloads/edge/test/car_104.jpg: 224x416 1 license_plate, Done. (0.081s)
# image 3/169 /home/abhireddy/Downloads/edge/test/car_108.jpg: 256x416 1 license_plate, Done. (0.076s)
# image 4/169 /home/abhireddy/Downloads/edge/test/car_120.jpg: 256x416 1 license_plate, Done. (0.079s)
# image 5/169 /home/abhireddy/Downloads/edge/test/car_121.jpg: 320x416 2 license_plates, Done. (0.088s)
# ...
